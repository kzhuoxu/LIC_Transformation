# %%
pip install pandas folium requests
# Out:
# Requirement already satisfied: pandas in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: folium in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (0.18.0)
# Requirement already satisfied: requests in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from folium) (3.1.4)
# Requirement already satisfied: xyzservices in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /Users/leihao/anaconda3/envs/ds/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import folium
import requests

# Fetch the station information data
url = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"
response = requests.get(url)
data = response.json()

# Extract station information
stations = data['data']['stations']

# Create a DataFrame
df = pd.DataFrame(stations)

# Create a map centered on New York City
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Add markers for each station
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=row['name'],
        tooltip=row['name']
    ).add_to(nyc_map)

# %%
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c30131e5e1d4abf6e1595c4b94ec1f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c30131e5e1d4abf6e1595c4b94ec1f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c30131e5e1d4abf6e1595c4b94ec1f7 = L.map(
#                 &quot;map_1c30131e5e1d4abf6e1595c4b94ec1f7&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9998450e624c3153dd1a50a709d66e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c30131e5e1d4abf6e1595c4b94ec1f7);
#
#
#             var marker_ab4c99c8c415e8a35aeb91c721b6ca69 = L.marker(
#                 [40.77423301703027, -73.91274864321404],
#                 {}
#             ).addTo(map_1c30131e5e1d4abf6e1595c4b94ec1f7);
#
#
#         var popup_7ee94cd1cff4273a66edab1acb18ba2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e93bdd3fe0881d22b4faaf1466570bf9 = $(`&lt;div id=&quot;html_e93bdd3fe0881d22b4faaf1466570bf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23 Ave &amp; 31 St&lt;/div&gt;`)[0];
#                 popup_7ee94cd1cff4273a66edab1acb18ba2a.setContent(html_e93bdd3fe0881d22b4faaf1466570bf9);
#
#
#
#         marker_ab4c99c8c415e8a35aeb91c721b6ca69.bindPopup(popup_7ee94cd1cff4273a66edab1acb18ba2a)
#         ;
#
#
#
#
#             marker_ab4c99c8c415e8a35aeb91c721b6ca69.bindTooltip(
#                 `&lt;div&gt;
#                      23 Ave &amp; 31 St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b98d74fb898ee2464a4da05024cc36a9 = L.marker(
#                 [40.7921, -73.9739],
#                 {}
#             ).addTo(map_1c30131e5e1d4abf6e1595c4b94ec1f7);
#
#
#         var popup_e598ea11fe6c945560b2c6b8bf1a398a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9e30bbb01eac4188d7686947e018f21 = $(`&lt;div id=&quot;html_f9e30bbb01eac4188d7686947e018f21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W 92 St &amp; Broadway&lt;/div&gt;`)[0];
#                 popup_e598ea11fe6c945560b2c6b8bf1a398a.setContent(html_f9e30bbb01eac4188d7686947e018f21);
#
#
#
#         marker_b98d74fb898ee2464a4da05024cc36a9.bindPopup(popup_e598ea11fe6c945560b2c6b8bf1a398a)
#         ;
#
#
#
#
#             marker_b98d74fb898ee2464a4da05024cc36a9.bindTooltip(
#                 `&lt;div&gt;
#                      W 92 St &amp; Broadway
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fecf8ab2bdda66a98f2ec7fc2a6d0ae5 = L.marker(
#                 [40.72467721, -73.98783413],
#                 {}
#             ).addTo(map_1c30131e5e1d4abf6e1595c4b94ec1f7);
#
#
#         var popup_6d46868367d8d92a411409bf7fb00d6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9760b589b58b2bdb94db4e647bca40ce = $(`&lt;div id=&quot;html_9760b589b58b2bdb94db4e647bca40ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E 3 St &amp; 1 Ave&lt;/div&gt;`)[0];
#                 popup_6d46868367d8d92a411409bf7fb00d6d.setContent(html_9760b589b58b2bdb94db4e647bca40ce);
#
#
#
#         marker_fecf8ab2bdda66a98f2ec7fc2a6d0ae5.bindPopup(popup_6d46868367d8d92a411409bf7fb00d6d)
#         ;
#
#
#
#
#             marker_fecf8ab2bdda66a98f2ec7fc2a6d0ae5.bindTooltip(
#                 `&lt;div&gt;
#                      E 3 St &amp; 1 Ave
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cbc1e97f81b0881b8355f7b2b9575aa4 = L.marker(
#                 [40.749372273899596, -73.89738768339157],
#                 {}
#             ).addTo(map_1c30131e5e1d4abf6e1595c4b94ec1f7);
#
#
#         var popup_44adffcfe3d5d73849c157ab3582f12f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8529d75ec5d944bff0a92f5690a392d = $(`&lt;div id=&quot;html_c8529d75ec5d944bff0a92f5690a392d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;65 St &amp; Broadway&lt;/div&gt;`)[0];
#                 popup_44adffcfe3d5d73849c157ab3582f12f.setContent(html_c8529d75ec5d944bff0a92f5690a392d);
#
#
#
#         marker_cbc1e97f81b0881b8355f7b2b9575aa4.bindPopup(popup_44adffcfe3d5d73849c157ab3582f12f)
#         ;
#
#
#
#
#             marker_cbc1e97f81b0881b8355f7b2b9575aa4.bindTooltip(
#                 `&lt;div&gt;
#                      65 St &amp; Broadway
